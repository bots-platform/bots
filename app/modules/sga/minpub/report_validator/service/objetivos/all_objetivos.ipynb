# %%
import pandas as pd

from typing import List, Dict
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_info_columns', 10000)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
from pathlib import Path
import sys

# 1) Where is this notebook?
notebook_dir = Path.cwd()

# 2) Climb up until you get to the folder that contains "app/"
#    parents[2] goes up from objetivo_2 → notebooks → objetivos → …
#    count how many levels from objetivo_2 to BOTS_RPA: in your case it's 8 levels
project_root = notebook_dir.parents[6]

# 3) Insert it at front of sys.path
sys.path.insert(0, str(project_root))

# 4) Now imports of "app.…" will succeed

# %%
from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_1.objetivo_1 import validation_objetivo_1
from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_2.objetivo_2 import validation_objetivo_2
from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_3.objetivo_3 import validation_objetivo_3

# %%
from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_2.word_averias_extractor import extract_averias_table
#from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_2.word_info_tecnico_extractor import extract_tecnico_reports
from app.modules.sga.minpub.report_validator.service.objetivos.calculations import extract_tecnico_reports_without_hours_last_dates
#from app.modules.sga.minpub.report_validator.service.objetivos.objetivo_3.word_indisp_anexos_extractor import extract_indisponibilidad_anexos
from app.modules.sga.minpub.report_validator.service.objetivos.calculations import extract_indisponibilidad_anexos

# %%
from app.modules.sga.minpub.report_validator.service.objetivos.preprocessing import ( 
    preprocess_335, preprocess_380, preprocess_corte_excel,
    preprocess_df_cid_cuismp_sharepoint, preprocess_df_word_datos_averias,
    preprocess_df_word_telefonia_averias, preprocess_df_word_datos_informe_tecnico,
    preprocess_df_word_telefonia_informe_tecnico ,preprocess_df_word_datos_anexos_indis,
    preprocess_df_word_telefonia_anexos_indis,
)

# %%
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_sga_335_corte_excel_sharepoint_cuismp_sga380 import ( 
merge_sga_335_corte_excel_sharepoint_cuismp_sga380
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_datos_averias_corte_excel import ( 
merge_word_datos_averias_corte_excel
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_telefonia_averias_corte_excel import ( 
merge_word_telefonia_averias_corte_excel
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_datos_informe_corte_excel import ( 
merge_word_datos_informe_corte_excel
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_telefonia_informe_corte_excel import ( 
merge_word_telefonia_informe_corte_excel
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_datos_anexos_disponibilidad_dfs_merged_sga import ( 
merge_word_datos_anexos_disponibilidad_df_merged_sga
)
from app.modules.sga.minpub.report_validator.service.objetivos.mergers.merge_word_telefonia_anexos_disponibilidad_dfs_merged_sga import ( 
merge_word_telefonia_anexos_disponibilidad_df_merged_sga
)

# %%
BASE_DIR = Path.cwd().parent.parent.parent.parent.parent.parent.parent
SAVE_DIR_EXTRACT_EXCEL = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "excel"/ "CORTE 2 30.03.25 AL 06.04.25.xlsx"
SAVE_DIR_EXTRACT_SGA_335 = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "sga_335" / "sga_reporte_15-03-2025_06-04-2025_20250429_210214.xlsx"
CID_CUISMP_PATH = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "sharepoint_cid_cuismp" / "MINPU - CID-CUISMP - AB (1)_20250429_210918.xlsx"
DIR_PARADAS_RELOJ = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "pausa_cliente" / "sga_reporte_15-03-2025_06-04-2025_20250429_213105.xlsx"
DIR_WORD_DATOS = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "word_datos" / "COMPONENTE 2-DATOS - CORTE 2 (002).docx"
DIR_WORD_TELEFONIA = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "word_telefonia" / "COMPONENTE 4 - TELEFONOS - CORTE 2 (002).docx"

# %%
def all_objetivos(
    path_corte_excel, 
    path_sgq_dinamico_335, 
    path_sga_dinamico_380,
    path_cid_cuismp_sharepoint,
    word_datos_file_path,
    word_telefonia_file_path

) -> List[Dict]:
    """
    Calls each objective's validation function and combines the results.
    Each objective function returns a DataFrame with the columns:
      - 'numero de incidencia'
      - 'mensaje'
      - 'objetivo'
    
    Returns:
      A list of dictionaries (one per incident that fails at least one validation)
      across all objectives.
    """
    results = []
    
    # extract
    df_corte_excel = pd.read_excel(path_corte_excel, skipfooter=2, engine="openpyxl")
    df_sga_dinamico_335 = pd.read_excel(path_sgq_dinamico_335) 
    df_sga_dinamico_380 = pd.read_excel(path_sga_dinamico_380)
    df_cid_cuismp_sharepoint = pd.read_excel(path_cid_cuismp_sharepoint)
    df_word_datos_averias =  extract_averias_table(word_datos_file_path)
    df_word_telefonia_averias = extract_averias_table(word_telefonia_file_path)
    df_word_datos_informe_tec =  extract_tecnico_reports_without_hours_last_dates(word_datos_file_path)
    df_word_telefonia_informe_tec = extract_tecnico_reports_without_hours_last_dates(word_telefonia_file_path)
    df_word_datos_anexos_indis =  extract_indisponibilidad_anexos(word_datos_file_path)
    df_word_telefonia_anexos_indis = extract_indisponibilidad_anexos(word_telefonia_file_path)


    # preprocess
    df_word_datos_averias = preprocess_df_word_datos_averias(df_word_datos_averias)
    df_word_telefonia_averias = preprocess_df_word_telefonia_averias(df_word_telefonia_averias)
    
    df_word_datos_informe_tec =  preprocess_df_word_datos_informe_tecnico(df_word_datos_informe_tec)
    df_word_telefonia_informe_tec = preprocess_df_word_telefonia_informe_tecnico(df_word_telefonia_informe_tec)

    df_word_datos_anexos_indis = preprocess_df_word_datos_anexos_indis(df_word_datos_anexos_indis)
    df_word_telefonia_anexos_indis = preprocess_df_word_telefonia_anexos_indis(df_word_telefonia_anexos_indis)

    df_sga_dinamico_335 = preprocess_335(df_sga_dinamico_335)
    df_sga_dinamico_380 = preprocess_380(df_sga_dinamico_380)
    df_corte_excel = preprocess_corte_excel(df_corte_excel)
    df_cid_cuismp_sharepoint = preprocess_df_cid_cuismp_sharepoint(df_cid_cuismp_sharepoint)
    

    # mergers 
    #  SGA 335 - 380 - SHAREPOINT - CORTE - BOTH
    df_matched_corte_sga335_Sharepoint_cuismp_sga380 = merge_sga_335_corte_excel_sharepoint_cuismp_sga380(
        df_corte_excel, df_sga_dinamico_335,
        df_cid_cuismp_sharepoint, df_sga_dinamico_380,
        'both'
        )
    
    #  SGA 335 - 380 - SHAREPOINT - CORTE - LEFT ONLY
    df_unmatched_corte_sga335_Sharepoint_cuismp_sga380 = merge_sga_335_corte_excel_sharepoint_cuismp_sga380(
        df_corte_excel,
        df_sga_dinamico_335,
        df_cid_cuismp_sharepoint,
        df_sga_dinamico_380,
        'left_only'
        )
    
    # AVERIAS - DATOS - EXCEL
    df_matched_word_datos_averias_corte_excel = merge_word_datos_averias_corte_excel(
        df_corte_excel,
        df_word_datos_averias,
        'both'
        )
   
    # AVERIAS - TELEFONIA - EXCEL
    df_matched_word_telefonia_averias_corte_excel = merge_word_telefonia_averias_corte_excel(
        df_word_telefonia_averias,
        df_corte_excel,
        'both'
        )
    
    #INFORME TECNICO - DATOS - EXCEL
    df_matched_word_datos_informe_tecnico_corte_excel = merge_word_datos_informe_corte_excel(
        df_word_datos_informe_tec,
        df_corte_excel,
        'both'
        )
    
    #INFORME TECNICO - TELEFONIA - EXCEL
    df_matched_word_telefonia_informe_tecnico_corte_excel = merge_word_telefonia_informe_corte_excel(
        df_word_telefonia_informe_tec,
        df_corte_excel,
        'both'
        )
    

    #ANEXOS INDISPONIBILIDAD - DATOS - EXCEL
    df_matched_word_datos_anexo_indisponibilidad_df_merged_sga = merge_word_datos_anexos_disponibilidad_df_merged_sga(
        df_word_datos_anexos_indis,
        df_matched_corte_sga335_Sharepoint_cuismp_sga380,
        'both'
        )
    
    #ANEXOS INDISPONIBILIDAD - TELEFONIA - EXCEL
    df_matched_word_telefonia_anexo_indisponibilidad_df_merged_sga = merge_word_telefonia_anexos_disponibilidad_df_merged_sga(
        df_word_telefonia_anexos_indis,
        df_matched_corte_sga335_Sharepoint_cuismp_sga380,
        'both'
        )
    

    # OBJETIVOS 

    obj1_df = validation_objetivo_1(
        df_matched_corte_sga335_Sharepoint_cuismp_sga380,
        df_unmatched_corte_sga335_Sharepoint_cuismp_sga380
        )

    obj2_df = validation_objetivo_2(
        df_matched_word_datos_averias_corte_excel,
        df_matched_word_telefonia_averias_corte_excel,
        df_matched_word_datos_informe_tecnico_corte_excel,
        df_matched_word_telefonia_informe_tecnico_corte_excel
        )
    
    obj3_df = validation_objetivo_3(
        df_matched_word_datos_anexo_indisponibilidad_df_merged_sga,
        df_matched_word_telefonia_anexo_indisponibilidad_df_merged_sga
    )   

    results.extend(obj1_df.to_dict(orient='records'))
    results.extend(obj2_df.to_dict(orient='records'))
    results.extend(obj3_df.to_dict(orient='records'))

    df_all = pd.DataFrame(results)

    df_grouped = (
        df_all
        .groupby('nro_incidencia', as_index=False)
        .agg({'mensaje': lambda msgs: ' | '.join(msgs),
              'objetivo': lambda objs: ' | '.join(objs), 
              'TIPO REPORTE': 'first', 
              })
    )

    #return df_grouped.to_dict(orient='records')
    return df_grouped


result_df = all_objetivos(
    SAVE_DIR_EXTRACT_EXCEL, 
    SAVE_DIR_EXTRACT_SGA_335, 
    DIR_PARADAS_RELOJ,
    CID_CUISMP_PATH,
    DIR_WORD_DATOS,
    DIR_WORD_TELEFONIA

)

result_df
# Out:
# No clock stops found for incident 21790147
# No clock stops found for incident 21790487
# No clock stops found for incident 21791695
# No clock stops found for incident 21792007
# No clock stops found for incident 21792345
# No clock stops found for incident 21792390
# No clock stops found for incident 21792405
# No clock stops found for incident 21792407
# No clock stops found for incident 21792453
# No clock stops found for incident 21792494
# No clock stops found for incident 21792500
# No clock stops found for incident 21792504
# No clock stops found for incident 21792509
# No clock stops found for incident 21793097
# Adjusting end time to interruption en for incident 21793573
# Adjusting end time to interruption en for incident 21793573
# Adjusting end time to interruption en for incident 21793573
# No clock stops found for incident 21795643
# No clock stops found for incident 21796219
# No clock stops found for incident 21796247
# No clock stops found for incident 21796252
# No clock stops found for incident 21796282
# No clock stops found for incident 21796323
# No clock stops found for incident 21796437
# No clock stops found for incident 21796489
# No clock stops found for incident 21796518
# No clock stops found for incident 21796590
# No clock stops found for incident 21796679
# No clock stops found for incident 21796814
# No clock stops found for incident 21796836
# No clock stops found for incident 21796838
# No clock stops found for incident 21796847
# No clock stops found for incident 21796848
# No clock stops found for incident 21796849
# No clock stops found for incident 21796850
# No clock stops found for incident 21796851
# No clock stops found for incident 21796852
# No clock stops found for incident 21796854
# No clock stops found for incident 21796856
# No clock stops found for incident 21796857
# No clock stops found for incident 21796858
# No clock stops found for incident 21796874
# No clock stops found for incident 21796903
# No clock stops found for incident 21796906
# No clock stops found for incident 21796909
# No clock stops found for incident 21796929
# No clock stops found for incident 21796938
# No clock stops found for incident 21796941
# No clock stops found for incident 21796964
# No clock stops found for incident 21797049
# No clock stops found for incident 21797157
# No clock stops found for incident 21797183
# No clock stops found for incident 21797201
# No clock stops found for incident 21797233
# No clock stops found for incident 21797235
# No clock stops found for incident 21797237
# No clock stops found for incident 21797242
# No clock stops found for incident 21797254
# No clock stops found for incident 21797264
# No clock stops found for incident 21797507
# No clock stops found for incident 21797509
# No clock stops found for incident 21797559
# No clock stops found for incident 21797560
# No clock stops found for incident 21797561
# No clock stops found for incident 21797564
# No clock stops found for incident 21797565
# No clock stops found for incident 21797618
# No clock stops found for incident 21797619
# No clock stops found for incident 21797655
# No clock stops found for incident 21797970
# No clock stops found for incident 21798138
# No clock stops found for incident 21798197
# No clock stops found for incident 21798205
# No clock stops found for incident 21798212
# No clock stops found for incident 21798257
# No clock stops found for incident 21798263
# No clock stops found for incident 21798285
# No clock stops found for incident 21798304
# Converted 05:07 to 307.0 seconds
# Converted 187:08 to 11228.0 seconds
# Converted 330:10 to 19810.0 seconds
# Converted 378:50 to 22730.0 seconds
# Converted 357:45 to 21465.0 seconds
# Converted 115:50 to 6950.0 seconds
# Converted 26:39 to 1599.0 seconds
# Converted 97:20 to 5840.0 seconds
# Converted 20:10 to 1210.0 seconds
# Converted 00:21 to 21.0 seconds
# Converted 111:13 to 6673.0 seconds
# Converted 08:59 to 539.0 seconds
# Converted 42:01 to 2521.0 seconds
# Converted 00:39 to 39.0 seconds
# Converted 02:06 to 126.0 seconds
# Converted 23:07 to 1387.0 seconds
# Converted 00:54 to 54.0 seconds
# Converted 06:03 to 363.0 seconds
# Converted 06:52 to 412.0 seconds
# Converted 15:52 to 952.0 seconds
# Converted 11:29 to 689.0 seconds
# Converted 11:33 to 693.0 seconds
# Converted 12:13 to 733.0 seconds
# Converted 06:24 to 384.0 seconds
# Converted 48:49 to 2929.0 seconds
# Converted 10:19 to 619.0 seconds
# Converted 21:59 to 1319.0 seconds
# Converted 73:23 to 4403.0 seconds
# Converted 52:23 to 3143.0 seconds
# Converted 02:00 to 120.0 seconds
# Converted 01:49 to 109.0 seconds
# Converted 01:32 to 92.0 seconds
# Converted 51:09 to 3069.0 seconds
# Converted 06:13 to 373.0 seconds
# Converted 07:42 to 462.0 seconds
# Converted 00:22 to 22.0 seconds
# Converted 21:09 to 1269.0 seconds
# Converted 01:54 to 114.0 seconds
# Converted 17:38 to 1058.0 seconds
# Converted 01:44 to 104.0 seconds
# Converted 18:01 to 1081.0 seconds
# Converted 17:47 to 1067.0 seconds
# Converted 00:21 to 21.0 seconds
# Converted 11:30 to 690.0 seconds
# Converted 11:37 to 697.0 seconds
# Converted 04:24 to 264.0 seconds
# Converted 12:06 to 726.0 seconds
# Converted 12:05 to 725.0 seconds
# Converted 12:04 to 724.0 seconds
# Converted 12:04 to 724.0 seconds
# Converted 12:03 to 723.0 seconds
# Converted 12:00 to 720.0 seconds
# Converted 11:58 to 718.0 seconds
# Converted 11:58 to 718.0 seconds
# Converted 11:57 to 717.0 seconds
# Converted 11:56 to 716.0 seconds
# Converted 05:54 to 354.0 seconds
# Converted 11:52 to 712.0 seconds
# Converted 02:53 to 173.0 seconds
# Converted 08:17 to 497.0 seconds
# Converted 00:04 to 4.0 seconds
# Converted 01:37 to 97.0 seconds
# Converted 01:29 to 89.0 seconds
# Converted 30:32 to 1832.0 seconds
# Converted 05:37 to 337.0 seconds
# Converted 09:15 to 555.0 seconds
# Converted 02:57 to 177.0 seconds
# Converted 00:37 to 37.0 seconds
# Converted 01:56 to 116.0 seconds
# Converted 19:56 to 1196.0 seconds
# Converted 19:24 to 1164.0 seconds
# Converted 19:23 to 1163.0 seconds
# Converted 19:21 to 1161.0 seconds
# Converted 19:19 to 1159.0 seconds
# Converted 19:04 to 1144.0 seconds
# Converted 18:51 to 1131.0 seconds
# Converted 18:08 to 1088.0 seconds
# Converted 19:13 to 1153.0 seconds
# Converted 16:02 to 962.0 seconds
# Converted 00:31 to 31.0 seconds
# Converted 00:30 to 30.0 seconds
# Converted 00:29 to 29.0 seconds
# Converted 00:26 to 26.0 seconds
# Converted 00:22 to 22.0 seconds
# Converted 04:38 to 278.0 seconds
# Converted 04:35 to 275.0 seconds
# Converted 03:54 to 234.0 seconds
# Converted 00:04 to 4.0 seconds
# Converted 01:46 to 106.0 seconds
# Converted 21:20 to 1280.0 seconds
# Converted 21:20 to 1280.0 seconds
# Converted 01:50 to 110.0 seconds
# Converted 17:58 to 1078.0 seconds
# Converted 00:54 to 54.0 seconds
# Converted 18:52 to 1132.0 seconds
# Converted 00:01 to 1.0 seconds
# Converted 01:23 to 83.0 seconds
# Converted 00:35 to 35.0 seconds
# Converted 00:12 to 12.0 seconds
# Converted 02:07 to 127.0 seconds
# Converted 07:29 to 449.0 seconds
# Converted 03:21 to 201.0 seconds
# Converted 01:48 to 108.0 seconds
# Converted 03:47 to 227.0 seconds
# Converted 03:44 to 224.0 seconds
# Converted 02:38 to 158.0 seconds
# Converted 01:31 to 91.0 seconds
# Converted 16:05 to 965.0 seconds
# Converted 00:22 to 22.0 seconds
# Converted 00:13 to 13.0 seconds
# Converted 00:17 to 17.0 seconds
# Converted 00:05 to 5.0 seconds
# Converted 02:13 to 133.0 seconds
# Converted 03:01 to 181.0 seconds
# Converted 00:40 to 40.0 seconds
# Converted 00:53 to 53.0 seconds
# Converted 00:43 to 43.0 seconds
# Converted 03:18 to 198.0 seconds
# Converted 00:31 to 31.0 seconds
# Converted 06:47 to 407.0 seconds
# Converted 04:21 to 261.0 seconds
# Converted 10:33 to 633.0 seconds
# Converted 10:32 to 632.0 seconds
# Converted 10:32 to 632.0 seconds
# Converted 10:20 to 620.0 seconds
# Converted 10:18 to 618.0 seconds
# Converted 10:12 to 612.0 seconds
# Converted 06:19 to 379.0 seconds
# Converted 03:08 to 188.0 seconds
# Converted 25:54 to 1554.0 seconds
# Converted 02:39 to 159.0 seconds
# Converted 02:35 to 155.0 seconds
# Converted 01:45 to 105.0 seconds
# Converted 01:44 to 104.0 seconds
# Converted 01:42 to 102.0 seconds
# Converted 00:06 to 6.0 seconds
# Converted 00:52 to 52.0 seconds
# Converted 02:31 to 151.0 seconds
# Converted 00:30 to 30.0 seconds
# Converted 00:04 to 4.0 seconds
# Converted 39:32 to 2372.0 seconds
# Converted 13:31 to 811.0 seconds
# Converted 07:25 to 445.0 seconds
# Converted 03:30 to 210.0 seconds
# Converted 15:34 to 934.0 seconds
# Converted 248.0 minutes to 04:08
# Converted 392.0 minutes to 06:32
# Converted 193.0 minutes to 03:13
# Converted 705.0 minutes to 11:45
# Converted 36.0 minutes to 00:36
# Converted 1591.0 minutes to 26:31
# Converted 307.0 minutes to 05:07
# Converted 541.0 minutes to 09:01
# Converted 388.0 minutes to 06:28
# Converted 316.0 minutes to 05:16
# Converted 366.0 minutes to 06:06
# Converted 1301.0 minutes to 21:41
# Converted 684.0 minutes to 11:24
# Converted 440.0 minutes to 07:20
# Converted 581.0 minutes to 09:41
# Converted 21.0 minutes to 00:21
# Converted 166.0 minutes to 02:46
# Converted 539.0 minutes to 08:59
# Converted 32.0 minutes to 00:32
# Converted 39.0 minutes to 00:39
# Converted 126.0 minutes to 02:06
# Converted 1387.0 minutes to 23:07
# Converted 54.0 minutes to 00:54
# Converted 2.0 minutes to 00:02
# Converted 412.0 minutes to 06:52
# Converted 952.0 minutes to 15:52
# Converted 689.0 minutes to 11:29
# Converted 693.0 minutes to 11:33
# Converted 733.0 minutes to 12:13
# Converted 3.0 minutes to 00:03
# Converted 996.0 minutes to 16:36
# Converted 619.0 minutes to 10:19
# Converted 404.0 minutes to 06:44
# Converted 220.0 minutes to 03:40
# Converted 3143.0 minutes to 52:23
# Converted 120.0 minutes to 02:00
# Converted 109.0 minutes to 01:49
# Converted 92.0 minutes to 01:32
# Converted 10.0 minutes to 00:10
# Converted 373.0 minutes to 06:13
# Converted 462.0 minutes to 07:42
# Converted 22.0 minutes to 00:22
# Converted 1269.0 minutes to 21:09
# Converted 114.0 minutes to 01:54
# Converted 109.0 minutes to 01:49
# Converted 104.0 minutes to 01:44
# Converted 136.0 minutes to 02:16
# Converted 58.0 minutes to 00:58
# Converted 21.0 minutes to 00:21
# Converted 690.0 minutes to 11:30
# Converted 697.0 minutes to 11:37
# Converted 264.0 minutes to 04:24
# Converted 726.0 minutes to 12:06
# Converted 725.0 minutes to 12:05
# Converted 724.0 minutes to 12:04
# Converted 724.0 minutes to 12:04
# Converted 723.0 minutes to 12:03
# Converted 720.0 minutes to 12:00
# Converted 718.0 minutes to 11:58
# Converted 718.0 minutes to 11:58
# Converted 717.0 minutes to 11:57
# Converted 716.0 minutes to 11:56
# Converted 354.0 minutes to 05:54
# Converted 712.0 minutes to 11:52
# Converted 173.0 minutes to 02:53
# Converted 497.0 minutes to 08:17
# Converted 4.0 minutes to 00:04
# Converted 97.0 minutes to 01:37
# Converted 89.0 minutes to 01:29
# Converted 313.0 minutes to 05:13
# Converted 228.0 minutes to 03:48
# Converted 555.0 minutes to 09:15
# Converted 177.0 minutes to 02:57
# Converted 37.0 minutes to 00:37
# Converted 116.0 minutes to 01:56
# Converted 1196.0 minutes to 19:56
# Converted 1164.0 minutes to 19:24
# Converted 1163.0 minutes to 19:23
# Converted 1161.0 minutes to 19:21
# Converted 1159.0 minutes to 19:19
# Converted 1144.0 minutes to 19:04
# Converted 1131.0 minutes to 18:51
# Converted 128.0 minutes to 02:08
# Converted 204.0 minutes to 03:24
# Converted 9.0 minutes to 00:09
# Converted 31.0 minutes to 00:31
# Converted 30.0 minutes to 00:30
# Converted 29.0 minutes to 00:29
# Converted 26.0 minutes to 00:26
# Converted 22.0 minutes to 00:22
# Converted 278.0 minutes to 04:38
# Converted 275.0 minutes to 04:35
# Converted 234.0 minutes to 03:54
# Converted 4.0 minutes to 00:04
# Converted 106.0 minutes to 01:46
# Converted 192.0 minutes to 03:12
# Converted 122.0 minutes to 02:02
# Converted 70.0 minutes to 01:10
# Converted 162.0 minutes to 02:42
# Converted 54.0 minutes to 00:54
# Converted 441.0 minutes to 07:21
# Converted 1.0 minutes to 00:01
# Converted 83.0 minutes to 01:23
# Converted 35.0 minutes to 00:35
# Converted 12.0 minutes to 00:12
# Converted 127.0 minutes to 02:07
# Converted 449.0 minutes to 07:29
# Converted 201.0 minutes to 03:21
# Converted 108.0 minutes to 01:48
# Converted 227.0 minutes to 03:47
# Converted 224.0 minutes to 03:44
# Converted 158.0 minutes to 02:38
# Converted 91.0 minutes to 01:31
# Converted 554.0 minutes to 09:14
# Converted 22.0 minutes to 00:22
# Converted 13.0 minutes to 00:13
# Converted 17.0 minutes to 00:17
# Converted 5.0 minutes to 00:05
# Converted 133.0 minutes to 02:13
# Converted 181.0 minutes to 03:01
# Converted 40.0 minutes to 00:40
# Converted 53.0 minutes to 00:53
# Converted 43.0 minutes to 00:43
# Converted 198.0 minutes to 03:18
# Converted 31.0 minutes to 00:31
# Converted 407.0 minutes to 06:47
# Converted 261.0 minutes to 04:21
# Converted 633.0 minutes to 10:33
# Converted 632.0 minutes to 10:32
# Converted 632.0 minutes to 10:32
# Converted 620.0 minutes to 10:20
# Converted 618.0 minutes to 10:18
# Converted 612.0 minutes to 10:12
# Converted 257.0 minutes to 04:17
# Converted 188.0 minutes to 03:08
# Converted 1554.0 minutes to 25:54
# Converted 159.0 minutes to 02:39
# Converted 155.0 minutes to 02:35
# Converted 105.0 minutes to 01:45
# Converted 104.0 minutes to 01:44
# Converted 102.0 minutes to 01:42
# Converted 6.0 minutes to 00:06
# Converted 1.0 minutes to 00:01
# Converted 151.0 minutes to 02:31
# Converted 30.0 minutes to 00:30
# Converted 4.0 minutes to 00:04
# Converted 2372.0 minutes to 39:32
# Converted 811.0 minutes to 13:31
# Converted 445.0 minutes to 07:25
# Converted 210.0 minutes to 03:30
# Converted 934.0 minutes to 15:34
# columnas disponibles:  ['nro_incidencia', 'FECHA Y HORA INICIO', 'FECHA Y HORA FIN', 'ESTATUS', 'SERVICIO', 'CUISMP_word_datos_averias', 'TIPO CASO', 'AVERÍA', 'TIEMPO (HH:MM)', 'COMPONENTE', 'DF', 'DIRECCION', 'OBSERVACIÓN', 'CID', 'FIN-INICIO (HH:MM)', 'DETERMINACIÓN DE LA CAUSA', 'RESPONSABILIDAD', 'TIPO REPORTE', 'Duracion entero', 'Agrupación entero', 'USUARIO', 'ESPECIALISTA', 'CODINCIDENCEPADRE', 'MASIVO', 'MEDIDAS CORRECTIVAS Y/O PREVENTIVAS TOMADAS', 'TIPO DE INCIDENCIA', 'TIEMPO INTERRUPCION', 'INDISPONIBILIDAD', 'DC + INDISPONIBILIDAD', 'TIEMPO (HH:MM)_trimed', 'FIN-INICIO (HH:MM)_trimed', 'FECHA_Y_HORA_INICIO_fmt', 'FECHA_Y_HORA_FIN_fmt', 'N°', 'CUISMP_corte_excel', 'Fecha y Hora Inicio', 'Fecha y Hora Fin', 'Avería reportada', 'Causa', 'Tiempo real de afectación (HH:MM)', 'Tiempo Total (HH:MM)', 'Distrito Fiscal', 'responsable', '_merge', 'Componente', 'cuismp_word_averia', 'Fecha_hora_inicio_match', 'fecha_hora_fin_match', 'CUISMP_match', 'tipo_caso_match', 'averia_match', 'tiempo_hhmm_match', 'componente_match', 'df_match']
# columnas disponibles:  ['N°', 'nro_incidencia', 'CUISMP_word_telefonia_averias', 'Fecha y Hora Inicio', 'Fecha y Hora Fin', 'Avería reportada', 'Causa', 'Tiempo real de afectación (HH:MM)', 'Tiempo Total (HH:MM)', 'Distrito Fiscal', 'responsable', 'FECHA Y HORA INICIO', 'FECHA Y HORA FIN', 'ESTATUS', 'SERVICIO', 'CUISMP_corte_excel', 'TIPO CASO', 'AVERÍA', 'TIEMPO (HH:MM)', 'COMPONENTE', 'DF', 'DIRECCION', 'OBSERVACIÓN', 'CID', 'FIN-INICIO (HH:MM)', 'DETERMINACIÓN DE LA CAUSA', 'RESPONSABILIDAD', 'TIPO REPORTE', 'Duracion entero', 'Agrupación entero', 'USUARIO', 'ESPECIALISTA', 'CODINCIDENCEPADRE', 'MASIVO', 'MEDIDAS CORRECTIVAS Y/O PREVENTIVAS TOMADAS', 'TIPO DE INCIDENCIA', 'TIEMPO INTERRUPCION', 'INDISPONIBILIDAD', 'DC + INDISPONIBILIDAD', 'TIEMPO (HH:MM)_trimed', 'FIN-INICIO (HH:MM)_trimed', 'FECHA_Y_HORA_INICIO_fmt', 'FECHA_Y_HORA_FIN_fmt', '_merge', 'Componente', 'cuismp_word_averia', 'Fecha_hora_inicio_match', 'fecha_hora_fin_match', 'CUISMP_match', 'tipo_caso_match', 'averia_match', 'tiempo_hhmm_match', 'componente_match', 'df_match']
#     nro_incidencia  \
# 0         21789759
# 1         21789943
# 2         21790147
# 3         21790461
# 4         21790467
# 5         21790478
# 6         21790487
# 7         21790524
# 8         21790527
# 9         21790550
# 10        21790577
# 11        21790612
# 12        21790828
# 13        21791018
# 14        21791311
# 15        21791947
# 16        21792007
# 17        21792226
# 18        21792345
# 19        21792390
# 20        21792405
# 21        21792407
# 22        21792446
# 23        21792453
# 24        21792494
# 25        21792500
# 26        21792504
# 27        21792509
# 28        21792537
# 29        21792739
# 30        21793097
# 31        21793573
# 32        21795319
# 33        21795643
# 34        21796219
# 35        21796247
# 36        21796252
# 37        21796264
# 38        21796323
# 39        21796437
# 40        21796489
# 41        21796518
# 42        21796533
# 43        21796590
# 44        21796622
# 45        21796629
# 46        21796679
# 47        21796814
# 48        21796836
# 49        21796838
# 50        21796847
# 51        21796848
# 52        21796849
# 53        21796850
# 54        21796851
# 55        21796852
# 56        21796854
# 57        21796856
# 58        21796857
# 59        21796858
# 60        21796874
# 61        21796903
# 62        21796906
# 63        21796909
# 64        21796929
# 65        21796938
# 66        21796951
# 67        21796956
# 68        21797157
# 69        21797183
# 70        21797201
# 71        21797233
# 72        21797235
# 73        21797237
# 74        21797242
# 75        21797254
# 76        21797264
# 77        21797310
# 78        21797339
# 79        21797464
# 80        21797507
# 81        21797509
# 82        21797559
# 83        21797560
# 84        21797561
# 85        21797564
# 86        21797565
# 87        21797618
# 88        21797619
# 89        21797753
# 90        21797812
# 91        21797901
# 92        21797960
# 93        21797970
# 94        21798129
# 95        21798138
# 96        21798197
# 97        21798205
# 98        21798212
# 99        21798257
# 100       21798285
# 101       21798304
# 102       21798329
# 103       21798497
# 104       21798530
# 105       21798532
# 106       21798537
# 107       21798544
# 108       21798821
# 109       21798822
# 110       21798823
# 111       21798824
# 112       21798825
# 113       21798826
# 114       21798862
# 115       21798879
# 116       21798883
# 117       21798953
# 118       21798955
# 119       21798956
# 120       21798982
# 121       21799098
# 122       21799388
# 123       21799473
# 124       21799515
# 125       21799527
# 126       21799529
# 127       21799530
# 128       21799531
# 129       21799540
# 130       21799573
# 131       21799574
# 132       21799671
# 133       21799685
# 134       21799697
# 135       21799789
# 136       21799790
# 137       21799883
# 138       21799942
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   mensaje  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         No coincide total horas sin acceso a la sede de word indisponibilidad en anexos : (Total de horas sin acceso a la sede: 16:22horas) es diferente a sga  :  (Total de horas sin acceso a la sede: 16:22 horas).
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Periodo(s) inválido(s) CORTE -EXCEL : 18/03/2025 17:24:00 hasta el día 19/03/2025 7:00:00 ES DIFERENTE A SGA PAUSA CLIENTE SIN OVERLAP: 18/03/2025 17:24:00 hasta el día 19/03/2025 07:00:00.  |  No coincide Determinación de la causa de WORD informe técnico : El inconveniente se originó debido a un problema con el equipo de red satelital ubicado en la sede del cliente. es diferente a DETERMINACION DE LA CAUSA de Excel: El inconveniente se originó debido a un problema con el equipo de red satelital ubicado en la sedel cliente..
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   No coincide AVERÍA en EXCEL-CORTE:  (ALERTA EN EL GESTOR DE MONITOREO - SIN AFECTACIÓN DEL SERVICIO) con tipificacion problema en SGA 335: (INCONVENIENTES EN LAS POLITICAS DE CALIDAD DE SERVICIO-RECONFIGURACIÓN).
# ...
# 136                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          EN EXCEL - CORTE PROACTIVO: OBSERVACION  debe ser: ( Se generó código de atención (interno) para la revisión del servicio de datos de la sede Juliaca1 )  pero se obtuvo ( Se generó ticket para la revisión del servicio de datos de la sede Juliaca1 ).  |  La fecha de inicio del parrafo en it_medidas_tomadas:  ( 05/04/2025 22:37 ) no coincide con la fecha inicio de la penultima fila: 05/04/2024 22:37.  La fecha de fin del parrafo en it_medidas_tomadas:( 06/04/2025 06:02 ) no coincide con la fecha fin de la ultima fila: 06/04/2024 06:02.
# 137                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         EN EXCEL - CORTE PROACTIVO: OBSERVACION  debe ser: ( Se generó código de atención (interno) para la revisión del servicio de datos de la sede Arequipa )  pero se obtuvo ( Se generó ticket para la revisión del servicio de datos de la sede Chuquibamba ).
# 138                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          EN EXCEL - CORTE PROACTIVO: OBSERVACION  debe ser: ( Se generó código de atención (interno) para la revisión del servicio de datos de la sede Acobamba2 )  pero se obtuvo ( Se generó ticket para la revisión del servicio de datos de la sede Acobamba2 ).
#
#                    objetivo TIPO REPORTE
# 0                       3.1      RECLAMO
# 1                1.11 | 2.2      RECLAMO
# 2                       1.6      RECLAMO
# 3                      1.11      RECLAMO
# 4    1.5 | 1.8 | 1.11 | 2.2      RECLAMO
# 5                      1.11      RECLAMO
# 6                 1.6 | 2.2      RECLAMO
# 7                1.11 | 2.1      RECLAMO
# 8                       1.6      RECLAMO
# 9          1.6 | 1.11 | 3.1      RECLAMO
# 10         1.11 | 2.2 | 3.1      RECLAMO
# 11               1.11 | 2.2      RECLAMO
# 12         1.8 | 1.11 | 2.2      RECLAMO
# 13                1.5 | 2.2      RECLAMO
# 14               1.7 | 1.11    PROACTIVO
# 15               1.11 | 3.1      RECLAMO
# 16                      1.7    PROACTIVO
# 17               1.7 | 1.11    PROACTIVO
# 18                      1.7    PROACTIVO
# 19                1.7 | 1.8    PROACTIVO
# 20                1.7 | 1.8    PROACTIVO
# 21                      1.7    PROACTIVO
# 22         1.7 | 1.8 | 1.11    PROACTIVO
# 23                      1.7    PROACTIVO
# 24                      1.7    PROACTIVO
# 25                      1.7    PROACTIVO
# 26                      1.7    PROACTIVO
# 27                      1.7    PROACTIVO
# 28               1.7 | 1.11    PROACTIVO
# 29               1.8 | 1.11      RECLAMO
# 30                      2.2      RECLAMO
# 31               1.7 | 1.11      RECLAMO
# 32                      2.2      RECLAMO
# 33                      1.7    PROACTIVO
# 34                      1.7    PROACTIVO
# 35                      1.7    PROACTIVO
# 36                      2.2      RECLAMO
# 37               1.11 | 3.1      RECLAMO
# 38          1.8 | 2.2 | 3.1      RECLAMO
# 39                1.7 | 1.8    PROACTIVO
# 40                      1.7    PROACTIVO
# 41                      1.7    PROACTIVO
# 42               1.11 | 3.1      RECLAMO
# 43          1.1 | 1.8 | 2.1      RECLAMO
# 44               1.11 | 3.1      RECLAMO
# 45         1.6 | 1.11 | 3.1      RECLAMO
# 46                1.7 | 1.8    PROACTIVO
# 47                1.7 | 1.8    PROACTIVO
# 48                1.7 | 1.8    PROACTIVO
# 49                1.7 | 1.8    PROACTIVO
# 50                1.7 | 1.8    PROACTIVO
# 51                1.7 | 1.8    PROACTIVO
# 52                1.7 | 1.8    PROACTIVO
# 53                1.7 | 1.8    PROACTIVO
# 54                1.7 | 1.8    PROACTIVO
# 55                1.7 | 1.8    PROACTIVO
# 56                1.7 | 1.8    PROACTIVO
# 57                1.7 | 1.8    PROACTIVO
# 58                1.7 | 1.8    PROACTIVO
# 59                1.7 | 1.8    PROACTIVO
# 60                      1.7    PROACTIVO
# 61                      1.7    PROACTIVO
# 62                      1.7    PROACTIVO
# 63                1.5 | 1.7    PROACTIVO
# 64                      2.2      RECLAMO
# 65                      2.2      RECLAMO
# 66    1.1 | 1.7 | 1.8 | 3.1      RECLAMO
# 67               1.11 | 3.1      RECLAMO
# 68                      2.1      RECLAMO
# 69          1.5 | 1.7 | 1.8    PROACTIVO
# 70                      2.2      RECLAMO
# 71                      2.2      RECLAMO
# 72                      2.2      RECLAMO
# 73                      2.2      RECLAMO
# 74                      2.2      RECLAMO
# 75                      2.2      RECLAMO
# 76                      2.2      RECLAMO
# 77               1.7 | 1.11    PROACTIVO
# 78               1.11 | 3.1      RECLAMO
# 79               1.7 | 1.11    PROACTIVO
# 80                1.7 | 1.8    PROACTIVO
# 81                1.7 | 1.8    PROACTIVO
# 82                1.7 | 1.8    PROACTIVO
# 83                1.7 | 1.8    PROACTIVO
# 84                1.7 | 1.8    PROACTIVO
# 85                      1.7    PROACTIVO
# 86                      1.7    PROACTIVO
# 87                      1.7      RECLAMO
# 88                      1.7    PROACTIVO
# 89         1.7 | 1.8 | 1.11    PROACTIVO
# 90   1.6 | 1.11 | 2.2 | 3.1      RECLAMO
# 91         1.11 | 2.2 | 3.1      RECLAMO
# 92               1.11 | 3.1      RECLAMO
# 93                      1.7    PROACTIVO
# 94               1.7 | 1.11    PROACTIVO
# 95                      1.7    PROACTIVO
# 96                1.7 | 1.8    PROACTIVO
# 97                      1.7    PROACTIVO
# 98                1.7 | 1.8    PROACTIVO
# 99                      1.8      RECLAMO
# 100                     1.7    PROACTIVO
# 101                     1.7    PROACTIVO
# 102                     2.1      RECLAMO
# 103        1.11 | 2.2 | 3.1      RECLAMO
# 104               1.7 | 1.8    PROACTIVO
# 105                     1.7    PROACTIVO
# 106                     1.7    PROACTIVO
# 107                     1.7    PROACTIVO
# 108                     1.7    PROACTIVO
# 109                     1.7    PROACTIVO
# 110                     1.7    PROACTIVO
# 111                     1.7    PROACTIVO
# 112                     1.7    PROACTIVO
# 113                     1.7    PROACTIVO
# 114                     2.2      RECLAMO
# 115               1.5 | 2.2      RECLAMO
# 116                     1.7    PROACTIVO
# 117               1.7 | 1.8    PROACTIVO
# 118               1.7 | 1.8    PROACTIVO
# 119               1.7 | 1.8    PROACTIVO
# 120                     2.2      RECLAMO
# 121              1.7 | 1.11    PROACTIVO
# 122                     1.7    PROACTIVO
# 123                     1.7    PROACTIVO
# 124         1.5 | 1.7 | 1.8    PROACTIVO
# 125                     1.7    PROACTIVO
# 126               1.7 | 1.8    PROACTIVO
# 127                     1.7    PROACTIVO
# 128                     1.7    PROACTIVO
# 129                     1.7    PROACTIVO
# 130                     1.7    PROACTIVO
# 131                     1.7    PROACTIVO
# 132               1.7 | 1.8    PROACTIVO
# 133               1.1 | 1.7    PROACTIVO
# 134                     1.7    PROACTIVO
# 135               1.7 | 1.8    PROACTIVO
# 136               1.7 | 1.8    PROACTIVO
# 137                     1.7    PROACTIVO
# 138                     1.7    PROACTIVO

# %%
from datetime import datetime
BASE_DIR = Path.cwd().parent.parent.parent.parent.parent.parent.parent
timestamp = datetime.now().strftime('%Y-%m-%d_%d_%H%M')
SAVE_FINAL_PATH = BASE_DIR / "media" / "minpub" / "validator_report" / "extract" / "final" / f"validacion_total_{timestamp}.xlsx"

result_df.to_excel(SAVE_FINAL_PATH, index=False)
print(f"file saved")
# Out:
# file saved
